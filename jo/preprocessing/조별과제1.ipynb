# %%
import pandas as pd

# 파일 경로
file_path = r"C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\01-1.정식개방데이터\Training\01.원천데이터\tn_travel_여행_B.csv"

# CSV 파일 읽기
df = pd.read_csv(file_path, encoding='utf-8')  # 혹시 글자가 깨지면 'cp949'로 바꿔보세요

# 컬럼명 변경
df = df.rename(columns={
    'TRAVEL_ID': '여행ID',
    'TRAVEL_NM': '여행명',
    'TRAVELER_ID': '여행객 ID', 
    'TRAVEL_PURPOSE' : '여행 목적',
    'TRAVEL_START_YMD' : '여행시작일자',
    'TRAVEL_END_YMD' : '여행종료일자',
    'MVMN_NM' : '주요이동수단',
    'TRAVEL_PERSONA' : '페르소나',
    'TRAVEL_MISSION' : '개별미션',
    'TRAVEL_MISSION_CHECK' : '미션우선도'
    })

# 결과 확인 (처음 5행만 출력)
print(df.head())


# 또는 전체 컬럼명만 출력해서 순서 확인
print("\n컬럼명 순서 확인:")
print(df.columns.tolist())


# 같은 폴더에 저장할 새로운 파일 경로 만들기
output_path = file_path.replace("tn_travel_여행_B.csv", "tn_travel_여행_B_컬럼수정.csv")

# 파일 저장 (Excel에서 열기 쉽게 utf-8-sig로 인코딩)
df.to_csv(output_path, index=False, encoding='utf-8-sig')

# 저장 완료 메시지 출력
print(f"\n변경된 파일이 저장되었습니다: {output_path}")
# Out:
#         여행ID  여행명   여행객 ID          여행 목적      여행시작일자      여행종료일자  주요이동수단  \
# 0  b_b015715  B04  b015715            22;  2022-10-29  2022-10-30  대중교통 등
# 1  b_b000419  B01  b000419            21;  2022-08-06  2022-08-08     자가용
# 2  b_b013638  B01  b013638            28;  2022-11-05  2022-11-06     NaN
# 3  b_b007836  B02  b007836  13;24;26;3;4;  2022-10-18  2022-10-19  대중교통 등
# 4  b_b004718  B04  b004718      1;26;6;9;  2022-10-01  2022-10-03  대중교통 등
#
#                   페르소나           개별미션    미션우선도
# 0                  NaN            22;   22;4;1
# 1                  NaN             2;  21;11;5
# 2                  NaN            28;   3;6;21
# 3                  NaN  13;24;26;3;4;   26;6;3
# 4  경상권에 거주하는 39세 이하 커플      1;26;6;9;    9;6;1
#
# 컬럼명 순서 확인:
# ['여행ID', '여행명', '여행객 ID', '여행 목적', '여행시작일자', '여행종료일자', '주요이동수단', '페르소나', '개별미션', '미션우선도']
#
# 변경된 파일이 저장되었습니다: C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\01-1.정식개방데이터\Training\01.원천데이터\tn_travel_여행_B_컬럼수정.csv

# %%
import pandas as pd

# 파일 경로
file_path = r"C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\01-1.정식개방데이터\Training\01.원천데이터\tn_travel_여행_B.csv"

# CSV 파일 읽기
df = pd.read_csv(file_path, encoding='utf-8')  # 혹시 글자가 깨지면 'cp949'로 바꿔보세요

# 컬럼명 변경
df = df.rename(columns={
    'TRAVEL_ID': '여행ID',
    'TRAVEL_NM': '여행명',
    'TRAVELER_ID': '여행객 ID', 
    'TRAVEL_PURPOSE' : '여행 목적',
    'TRAVEL_START_YMD' : '여행시작일자',
    'TRAVEL_END_YMD' : '여행종료일자',
    'MVMN_NM' : '주요이동수단',
    'TRAVEL_PERSONA' : '페르소나',
    'TRAVEL_MISSION' : '개별미션',
    'TRAVEL_MISSION_CHECK' : '미션우선도'
    })

# 결과 확인 (처음 5행만 출력)
print(df.head())


# 또는 전체 컬럼명만 출력해서 순서 확인
print("\n컬럼명 순서 확인:")
print(df.columns.tolist())


# 같은 폴더에 저장할 새로운 파일 경로 만들기
output_path = file_path.replace("tn_travel_여행_B.csv", "tn_travel_여행_B_컬럼수정.csv")

# 파일 저장 (Excel에서 열기 쉽게 utf-8-sig로 인코딩)
df.to_csv(output_path, index=False, encoding='utf-8-sig')

# 저장 완료 메시지 출력
print(f"\n변경된 파일이 저장되었습니다: {output_path}")
# Out:
#         여행ID  여행명   여행객 ID          여행 목적      여행시작일자      여행종료일자  주요이동수단  \
# 0  b_b015715  B04  b015715            22;  2022-10-29  2022-10-30  대중교통 등
# 1  b_b000419  B01  b000419            21;  2022-08-06  2022-08-08     자가용
# 2  b_b013638  B01  b013638            28;  2022-11-05  2022-11-06     NaN
# 3  b_b007836  B02  b007836  13;24;26;3;4;  2022-10-18  2022-10-19  대중교통 등
# 4  b_b004718  B04  b004718      1;26;6;9;  2022-10-01  2022-10-03  대중교통 등
#
#                   페르소나           개별미션    미션우선도
# 0                  NaN            22;   22;4;1
# 1                  NaN             2;  21;11;5
# 2                  NaN            28;   3;6;21
# 3                  NaN  13;24;26;3;4;   26;6;3
# 4  경상권에 거주하는 39세 이하 커플      1;26;6;9;    9;6;1
#
# 컬럼명 순서 확인:
# ['여행ID', '여행명', '여행객 ID', '여행 목적', '여행시작일자', '여행종료일자', '주요이동수단', '페르소나', '개별미션', '미션우선도']
#
# 변경된 파일이 저장되었습니다: C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\01-1.정식개방데이터\Training\01.원천데이터\tn_travel_여행_B_컬럼수정.csv

# %%
import pandas as pd

# 파일 경로
file_path = r"C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\
01-1.정식개방데이터\Training\01.원천데이터\tn_traveller_master_여행객 Master_B.csv"


# CSV 파일 읽기
df = pd.read_csv(file_path, encoding='utf-8')  # 혹시 글자가 깨지면 'cp949'로 바꿔보세요

# 컬럼명 변경
df = df.rename(columns={
    'TRAVEL_ID': '여행ID',
    'MVMN_SE': '이동수단구분',
    'PAYMENT_SE': '이용경비구분', 
    'PAYMENT_SEQ' : '이용경비순번',
    'MVMN_SE_NM' : '이동수단구분명',
    'PAYMENT_NUM' : '포함인원',
    'BRNO' : '사업자등록번호',
    'STORE_NM' : '상호명',
    'PAYMENT_DT' : '결제일시_분',
    'PAYMENT_MTHD_SE' : '결제방식구분',
    'PAYMENT_AMT_WON' : '결제금액_원',
    'PAYMENT_ETC' : '소비내역_기타'
    })

# 결과 확인 (처음 5행만 출력)
print(df.head())


# 또는 전체 컬럼명만 출력해서 순서 확인
print("\n컬럼명 순서 확인:")
print(df.columns.tolist())


# 같은 폴더에 저장할 새로운 파일 경로 만들기
output_path = file_path.replace("tn_mvmn_consume_his_이동수단소비내역_B.csv", "tn_mvmn_consume_his_이동수단소비내역_B_컬럼수정.csv")

# 파일 저장 (Excel에서 열기 쉽게 utf-8-sig로 인코딩)
df.to_csv(output_path, index=False, encoding='utf-8-sig')

# 저장 완료 메시지 출력
print(f"\n변경된 파일이 저장되었습니다: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 9
#       4 file_path = r"C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\
#       5 01-1.정식개방데이터\Training\01.원천데이터\tn_mvmn_consume_his_이동수단소비내역_B.csv"
#       8 # CSV 파일 읽기
# ----> 9 df = pd.read_csv(file_path, encoding='utf-8')  # 혹시 글자가 깨지면 'cp949'로 바꿔보세요
#      11 # 컬럼명 변경
#      12 df = df.rename(columns={
#      13     'TRAVEL_ID': '여행ID',
#      14     'MVMN_SE': '이동수단구분',
#    (...)
#      24     'PAYMENT_ETC' : '소비내역_기타'
#      25     })
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 31
#      17 df = df.rename(columns={ 'TRAVEL_ID': '여행ID',
#      18     'TRAVEL_NM': '여행명',
#      19     'TRAVELER_ID': '여행객 ID',
#    (...)
#      27       # 중복 발생 가능성 있음
#      28 })
#      30 # 중복된 컬럼명 자동 수정 (예: '여행객 ID', '여행객 ID.1')
# ---> 31 df.columns = pd.io.parsers.ParserBase({'names':df.columns})._maybe_dedup_names(df.columns)
#      33 # 바뀐 파일 저장
#      34 df.to_csv(output_path, index=False, encoding='utf-8-sig')  # Excel 호환을 위해 utf-8-sig 사용
#
# AttributeError: module 'pandas.io.parsers' has no attribute 'ParserBase'

# %%
import pandas as pd

# 파일 경로
file_path = r"C:\Users\henaj\Downloads\278.국내 여행로그 데이터(동부권)\01-1.정식개방데이터\Training\01.원천데이터\tn_mvmn_consume_his_이동수단소비내역_B.csv"

# CSV 파일 읽기
df = pd.read_csv(file_path, encoding='utf-8')  # 혹시 글자가 깨지면 'cp949'로 바꿔보세요

# 컬럼명 변경
df = df.rename(columns={
    'TRAVEL_ID': '여행ID',
    'MVMN_SE': '이동수단구분',
    'PAYMENT_SE': '이용경비구분', 
    'PAYMENT_SEQ' : '이용경비순번',
    'MVMN_SE_NM' : '이동수단구분명',
    'PAYMENT_NUM' : '포함인원',
    'BRNO' : '사업자등록번호',
    'STORE_NM' : '상호명',
    'PAYMENT_DT' : '결제일시_분',
    'PAYMENT_MTHD_SE' : '결제방식구분',
    'PAYMENT_AMT_WON' : '결제금액_원',
    'PAYMENT_ETC' : '소비내역_기타'
    })

# 결과 확인 (처음 5행만 출력)
print(df.head())


# 또는 전체 컬럼명만 출력해서 순서 확인
print("\n컬럼명 순서 확인:")
print(df.columns.tolist())


# 같은 폴더에 저장할 새로운 파일 경로 만들기
output_path = file_path.replace("tn_mvmn_consume_his_이동수단소비내역_B.csv", "tn_mvmn_consume_his_이동수단소비내역_B_컬럼수정.csv")

# 파일 저장 (Excel에서 열기 쉽게 utf-8-sig로 인코딩)
df.to_csv(output_path, index=False, encoding='utf-8-sig')

# 저장 완료 메시지 출력
print(f"\n변경된 파일이 저장되었습니다: {output_path}")
# Out:
#         여행ID  이동수단구분 이용경비구분  이용경비순번           이동수단구분명  포함인원       사업자등록번호  \
# 0  b_b006423       1    주유비       0  자가용(승용/승합/트럭 등등)     2           NaN
# 1  b_b003926       1    주유비      12  자가용(승용/승합/트럭 등등)     2  5.488501e+09
# 2  b_b008189       1    통행료       0  자가용(승용/승합/트럭 등등)     2           NaN
# 3  b_b018641      50    교통비       0          버스 + 지하철     2           NaN
# 4  b_b002963       1    주차비       0  자가용(승용/승합/트럭 등등)     2           NaN
#
#      상호명                   결제일시_분  결제방식구분  결제금액_원 소비내역_기타
# 0    NaN                      NaN     NaN   30000     NaN
# 1  행복주유소  2022-10-03 11:12:00.000     1.0   36777     주유비
# 2    NaN                      NaN     NaN   22100     NaN
# 3    NaN                      NaN     NaN    6500     NaN
# 4    NaN                      NaN     NaN    2000     NaN
#
# 컬럼명 순서 확인:
# ['여행ID', '이동수단구분', '이용경비구분', '이용경비순번', '이동수단구분명', '포함인원', '사업자등록번호', '상호명', '결제일시_분', '결제방식구분', '결제금액_원', '소비내역_기타']
#
# ...
